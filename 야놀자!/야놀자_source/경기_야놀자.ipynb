# %%
import pandas as pd
import requests
import re
import json
import datetime
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
import time
import numpy
pd.set_option('display.max_row', 50000)
options = webdriver.ChromeOptions()

# %%
############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 수언 인계/권선/영통
sigy = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(1) > span')
sigy.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'


########### 데이터통합 및 csv
sigy = pd.concat([gm,gh,gg])
sigy.reset_index(drop=True,inplace=True)
sigy['loc'] = sigy['loc'].str.replace('•','-')
sigy['loc'] = sigy['loc'].str.replace('❤️','')
sigy['loc'] = sigy['loc'].str.replace('⭐','')
sigy.to_csv('수인권영.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 수원역/구운/장안/세류
sgjs = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(2) > span')
sgjs.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)


################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
sgjs = pd.concat([gm,gh,gg])
sgjs.reset_index(drop=True,inplace=True)
sgjs['loc'] = sgjs['loc'].str.replace('•','-')
sgjs['loc'] = sgjs['loc'].str.replace('❤️','')
sgjs.to_csv('수구장세.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 안양/평촌/인덕원/과천
apig = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(3) > span')
apig.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
apig = pd.concat([gm,gh])
apig.reset_index(drop=True,inplace=True)
apig['loc'] = apig['loc'].str.replace('•','-')
apig.to_csv('안평인과.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 성남/분당/위례
sbe = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(4) > span')
sbe.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)


########### 데이터통합 및 csv
sbe = pd.concat([gm,gh])
sbe.reset_index(drop=True,inplace=True)
sbe['loc'] = sbe['loc'].str.replace('•','-')
sbe.to_csv('성분위.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 용인
sbe = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(5) > span')
sbe.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)






################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.PlaceListTabs_active__fi3E1.swiper-slide-active > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'


########### 데이터통합 및 csv
yongin = pd.concat([gm,gh,gf,gg])
yongin.reset_index(drop=True,inplace=True)
yongin['loc'] = yongin['loc'].str.replace('•','-')
yongin.to_csv('용인.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 동탄/화성/오산/병점
dhob = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(6) > span')
dhob.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.PlaceListTabs_active__fi3E1.swiper-slide-active > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv
dhob = pd.concat([gm,gh,gf])
dhob.reset_index(drop=True,inplace=True)
dhob['loc'] = dhob['loc'].str.replace('•','-')
dhob.to_csv('동화오병.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 하남/광주/여주/이천
hkye = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(7) > span')
hkye.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
hkye = pd.concat([gm,gh,gf,gg])
hkye.reset_index(drop=True,inplace=True)
hkye['loc'] = hkye['loc'].str.replace('•','-')
hkye.to_csv('하광여이.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 안산
ansan = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(8) > span')
ansan.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
ansan = pd.concat([gm,gh])
ansan.reset_index(drop=True,inplace=True)
ansan['loc'] = ansan['loc'].str.replace('•','-')
ansan.to_csv('안산.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 군포/의왕/금정/산본
gegs = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(9) > span')
gegs.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
gegs = pd.concat([gm,gh])
gegs.reset_index(drop=True,inplace=True)
gegs['loc'] = gegs['loc'].str.replace('•','-')
gegs.to_csv('군의금산.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 시흥
sh = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(10) > span')
sh.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv
sih = pd.concat([gm,gh,gf])
sih.reset_index(drop=True,inplace=True)
sih['loc'] = sih['loc'].str.replace('•','-')
sih.to_csv('시흥.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 광명
gmm = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(11) > span')
gmm.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
gmm = pd.concat([gm,gh])
gmm.reset_index(drop=True,inplace=True)
gmm['loc'] = gmm['loc'].str.replace('•','-')
gmm.to_csv('광명.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)


############################################ 경기 -> 평택/송탄/안성
psa = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(12) > span')
psa.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv

psa = pd.concat([gm,gh,gf])
psa.reset_index(drop=True,inplace=True)
psa['loc'] = psa['loc'].str.replace('•','-')
psa['loc'] = psa['loc'].str.replace('❤️','')
psa.to_csv('평송안.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 부천
buc = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(13) > span')
buc.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
buc = pd.concat([gm,gh])
buc.reset_index(drop=True,inplace=True)
buc['loc'] = buc['loc'].str.replace('•','-')
buc.to_csv('부천.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)


############################################ 경기 -> 일산/고양
ig = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(14) > span')
ig.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
ig = pd.concat([gm,gh])
ig.reset_index(drop=True,inplace=True)
ig['loc'] = ig['loc'].str.replace('•','-')
ig.to_csv('일고.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################ 경기 -> 파주
paju = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(15) > span')
paju.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
paju = pd.concat([gm,gh,gf,gg])
paju.reset_index(drop=True,inplace=True)
paju['loc'] = paju['loc'].str.replace('•','-')
paju.to_csv('파주.csv',sep=',',encoding='cp949')
time.sleep(1)


############################################### 파주까지!

# %%
################################################## 김포부터!
################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)

############################################ 경기 -> 김포
gimpo = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(16) > span')
gimpo.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv
gimpo = pd.concat([gm,gh,gf])
gimpo.reset_index(drop=True,inplace=True)
gimpo['loc'] = gimpo['loc'].str.replace('•','-')
gimpo.to_csv('김포.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)

############################################ 경기 -> 의정부
ejb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(17)')
ejb.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
ejb = pd.concat([gm,gh])
ejb.reset_index(drop=True,inplace=True)
ejb['loc'] = ejb['loc'].str.replace('•','-')
ejb['loc'] = ejb['loc'].str.replace('❣','')
ejb.to_csv('의정부.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 구리
guri = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(18) > span')
guri.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)


########### 데이터통합 및 csv
guri = pd.concat([gm,gh])
guri.reset_index(drop=True,inplace=True)
guri['loc'] = guri['loc'].str.replace('•','-')
guri.to_csv('구리.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 남양주
nyj = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(19) > span')
nyj.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv
nyj = pd.concat([gm,gh,gf])
nyj.reset_index(drop=True,inplace=True)
nyj['loc'] = nyj['loc'].str.replace('•','-')
nyj.to_csv('남양주.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 포천
pochoen = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(20) > span')
pochoen.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
pocheon = pd.concat([gm,gh,gf,gg])
pocheon.reset_index(drop=True,inplace=True)
pocheon['loc'] = pocheon['loc'].str.replace('•','-')
pocheon.to_csv('포천.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)

############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 양주/동두천/연천
ydy = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(21) > span')
ydy.click()
time.sleep(2)


############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
ydy = pd.concat([gm,gh,gf,gg])
ydy.reset_index(drop=True,inplace=True)
ydy['loc'] = ydy['loc'].str.replace('•','-')
ydy.to_csv('양동연.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)


############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 양평
yp = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(22) > span')
yp.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==15:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'


########### 데이터통합 및 csv
yangpyeong = pd.concat([gm,gh,gf,gg])
yangpyeong.reset_index(drop=True,inplace=True)
yangpyeong['loc'] = yangpyeong['loc'].str.replace('•','-')
yangpyeong.to_csv('양평.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
kg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
kg.click()
time.sleep(2)
############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()
############################################ 경기 -> 가평/청평
gc = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(23) > span')
gc.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==35:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5,6]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
            if ii%10 ==0:
                print(ii)
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
gc = pd.concat([gm,gh,gf,gg])
gc.reset_index(drop=True,inplace=True)
gc['loc'] = gc['loc'].str.replace('•','-')
gc['loc'] = gc['loc'].str.replace('❤️','')
gc.to_csv('가청.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)

############################################ 경기 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(2)')
jd.click()
time.sleep(2)
############################################### 스크롤 내리기 
element =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[3]/div')
element2 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[15]/i')
element3 =dv.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/div[1]/div/a[24]/i')
#final_xpath=xpath of scroll bar arrow button, mostly an img, or something like isc_B7end
actions = ActionChains(dv)
actions.move_to_element(element).click_and_hold().perform()
actions.move_to_element(element2).perform()
time.sleep(1)
actions.move_to_element(element3).perform()

############################################ 경기 -> 제부도/대부도
gc = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(24) > span')
gc.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==7:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5,6]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'


########### 데이터통합 및 csv
jd = pd.concat([gm,gf,gg])
jd.reset_index(drop=True,inplace=True)
jd['loc'] = jd['loc'].str.replace('•','-')
jd.to_csv('제대.csv',sep=',',encoding='cp949')
time.sleep(1)

dv.close()
