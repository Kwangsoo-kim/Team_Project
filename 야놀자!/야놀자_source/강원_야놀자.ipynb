# %%
import pandas as pd
import requests
import re
import json
import datetime
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
import time
import numpy
pd.set_option('display.max_row', 50000)

# %%
dv = webdriver.Chrome()
dv.get('https://www.yanolja.com/area?')

############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 춘천/강촌
cg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(1) > span')
cg.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==7:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
cg = pd.concat([gm,gh,gf,gg])
cg.reset_index(drop=True,inplace=True)
cg['loc'] = cg['loc'].str.replace('•','-')
cg.to_csv('춘강.csv',sep=',',encoding='cp949')
time.sleep(1)
################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)

############################################ 강원 -> 춘천/강촌
cg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(2) > span')
cg.click()
time.sleep(2)

############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==7:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
wonju = pd.concat([gm,gh,gf,gg])
wonju.reset_index(drop=True,inplace=True)
wonju['loc'] = wonju['loc'].str.replace('•','-')
wonju.to_csv('원주.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 경포대/사천/주문진/정동진
gsjj = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(3) > span')
gsjj.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==15:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
gsjj = pd.concat([gm,gh,gf,gg])
gsjj.reset_index(drop=True,inplace=True)
gsjj['loc'] = gsjj['loc'].str.replace('•','-')
gsjj.to_csv('경사주정.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)

############################################ 강원 -> 강릉/교동/옥계
ggo = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(4) > span')
ggo.click()
time.sleep(2)


############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
ggo = pd.concat([gm,gh,gf,gg])
ggo.reset_index(drop=True,inplace=True)
ggo['loc'] = ggo['loc'].str.replace('•','-')
ggo.to_csv('강교옥.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 영월/정선
yj = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(5) > span')
yj.click()
time.sleep(2)





############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==8:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
yj = pd.concat([gm,gh,gf,gg])
yj.reset_index(drop=True,inplace=True)
yj['loc'] = yj['loc'].str.replace('•','-')
yj.to_csv('영정.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 속초/고성
sg = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(6) > span')
sg.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==9:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
sg = pd.concat([gm,gh,gf,gg])
sg.reset_index(drop=True,inplace=True)
sg['loc'] = sg['loc'].str.replace('•','-')
sg.to_csv('속고.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)

############################################ 강원 -> 양양
yy = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(7) > span')
yy.click()
time.sleep(2)


############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==10:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
yy = pd.concat([gm,gh,gf,gg])
yy.reset_index(drop=True,inplace=True)
yy['loc'] = yy['loc'].str.replace('•','-')
yy.to_csv('양양.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)

############################################ 강원 -> 동해/삼척/태백
dst = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(8) > span')
dst.click()
time.sleep(2)



############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
dst = pd.concat([gm,gh,gf,gg])
dst.reset_index(drop=True,inplace=True)
dst['loc'] = dst['loc'].str.replace('•','-')
dst['loc'] = dst['loc'].str.replace('❤','')
dst.to_csv('동삼태.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 평창
pc = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(9) > span')
pc.click()
time.sleep(2)






############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==11:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
pc = pd.concat([gm,gh,gf,gg])
pc.reset_index(drop=True,inplace=True)
pc['loc'] = pc['loc'].str.replace('•','-')
pc.to_csv('평창.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 홍천/횡성
hh = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(10) > span')
hh.click()
time.sleep(2)


############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==14:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
hh = pd.concat([gm,gh,gf,gg])
hh.reset_index(drop=True,inplace=True)
hh['loc'] = hh['loc'].str.replace('•','-')
hh.to_csv('홍횡.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################ 강원 카테고리
jd = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(4)')
jd.click()
time.sleep(2)
############################################ 강원 -> 화천/철원/인제/양구
hciy = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(11) > span')
hciy.click()
time.sleep(2)



############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
################################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
hciy = pd.concat([gm,gh,gf,gg])
hciy.reset_index(drop=True,inplace=True)
hciy['loc'] = hciy['loc'].str.replace('•','-')
hciy.to_csv('화철인양.csv',sep=',',encoding='cp949')
time.sleep(1)

dv.close
