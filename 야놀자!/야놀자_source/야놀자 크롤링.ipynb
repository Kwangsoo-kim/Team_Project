# %%
import pandas as pd
import requests
import re
import json
import datetime
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
import time
import numpy

# %%
# selenium 이용 야놀자 크롤링

# %%
dv = webdriver.Chrome()
dv.get('https://www.yanolja.com/area?')

# %%
# 서울 -> 강남/역삼/삼성/논현
gysn = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(1) > span')
gysn.click()
time.sleep(1)

# %%
# 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()

# %%
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()

# %%
# 숙소 더보기
clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
cnt = 0
while True:
    clicks.click()
    cnt+=1
    time.sleep(1)
    if cnt==5:
        break

# %%
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()

# %%
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
i = 1
ii = 1
iii = 1
iiii = 1
# 지역 추천
while True:    
    try:
        rname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
        rscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
        rloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
        rprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(rname.text)
        score_list.append(rscore.text)
        loc_list.append(rloc.text)
        price_list.append(rprice.text)
        i+=1
    except:
        break

# %%
len(name_list),len(score_list),len(loc_list),len(price_list)
# Out:
# (26, 26, 26, 26)

# %%
# 프리미엄
while True:
    try:
        pname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
        pscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
        ploc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
        pprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(pname.text)
        score_list.append(pscore.text)
        loc_list.append(ploc.text)
        price_list.append(pprice.text)
        ii+=1
    except:
        break

# %%
len(name_list),len(score_list),len(loc_list),len(price_list)
# Out:
# (34, 34, 34, 34)

# %%
while True:
    try:
        bname

# %%
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list,
                  'score':score_list,
                  'loc':loc_list,
                  'lowest_price':price_list})

# %%
# 중복행 제거
gm=gm.drop_duplicates()

# %%
r_num = [1,2]
pbn_num = [3,4,5]

# %%
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            rname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            rscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            rloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            rprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(rname.text)
            score_list.append(rscore.text)
            loc_list.append(rloc.text)
            price_list.append(rprice.text)
            i+=1
        except:
            break

# %%
len(name_list),len(score_list),len(loc_list),len(price_list)
# Out:
# (27, 27, 27, 27)

# %%
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []

for li in pbn_num:
    ii = 1
    # 프리미엄
    # 일반
    while True:
        try:
            pname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            pscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            ploc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            pprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(pname.text)
            score_list.append(pscore.text)
            loc_list.append(ploc.text)
            price_list.append(pprice.text)
            ii+=1
        except:
            break

# %%
len(name_list),len(score_list),len(loc_list),len(price_list)
# Out:
# (55, 54, 54, 54)

# %%
price_list
# Out:
# ['42,000원',
#  '49,800원',
#  '50,000원',
#  '49,800원',
#  '56,800원',
#  '60,000원',
#  '50,000원',
#  '40,000원',
#  '49,800원',
#  '49,800원',
#  '50,000원',
#  '50,000원',
#  '56,000원',
#  '75,000원',
#  '40,000원',
#  '45,000원',
#  '45,000원',
#  '50,000원',
#  '50,000원',
#  '50,000원',
#  '45,000원',
#  '70,000원',
#  '45,000원',
#  '50,000원',
#  '40,000원',
#  '50,000원',
#  '50,000원',
#  '49,000원',
#  '45,000원',
#  '55,000원',
#  '45,000원',
#  '45,000원',
#  '40,000원',
#  '43,000원',
#  '50,000원',
#  '50,000원',
#  '45,000원',
#  '35,000원',
#  '40,000원',
#  '40,000원',
#  '50,000원',
#  '55,000원',
#  '35,000원',
#  '45,000원',
#  '45,000원',
#  '40,000원',
#  '45,000원',
#  '50,000원',
#  '50,000원',
#  '50,000원',
#  '50,000원',
#  '120,000원',
#  '80,000원',
#  '70,000원']

# %%
#강남/역삼/삼성/논현 모텔
dv = webdriver.Chrome()
dv.get('https://www.yanolja.com/area?')
time.sleep(2)
# 서울 -> 강남/역삼/삼성/논현
gysn = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(1) > span')
gysn.click()
time.sleep(2)
# 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 숙소 더보기
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
i = 1
ii = 1
iii = 1
iiii = 1
# 지역 인기 추천
while True:    
    try:
        bname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
        bscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
        bloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
        bprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(bname.text)
        score_list.append(bscore.text)
        loc_list.append(bloc.text)
        price_list.append(bprice.text)
        i+=1
    except:
        break
# 지역 추천 (1개)
sname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
sscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
sloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
sprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
name_list.append(sname.text)
score_list.append(sscore.text)
loc_list.append(sloc.text)
price_list.append(sprice.text)
# 프리미엄
while True:
    try:
        pname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
        pscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
        ploc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
        pprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(pname.text)
        score_list.append(pscore.text)
        loc_list.append(ploc.text)
        price_list.append(pprice.text)
        ii+=1
    except:
        break
# 베스트
while True:
    try:
        name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(4) > div > div:nth-child('+str(iii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
        score = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(4) > div > div:nth-child('+str(iii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
        loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(4) > div > div:nth-child('+str(iii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
        price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(4) > div > div:nth-child('+str(iii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(name.text)
        score_list.append(score.text)
        loc_list.append(loc.text)
        price_list.append(price.text)
        iii+=1
    except:
        break
# 일반
while True:
    try:
        nname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(5) > div > div:nth-child('+str(iiii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
        nscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(5) > div > div:nth-child('+str(iiii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
        nloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(5) > div > div:nth-child('+str(iiii)+') > a > div > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
        nprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(5) > div > div:nth-child('+str(iiii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(nname.text)
        score_list.append(nscore.text)
        loc_list.append(nloc.text)
        price_list.append(nprice.text)
        iiii+=1
    except:
        break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

# %%
gm
# Out:
#                      name score                                 loc  \
# 0             논현(신사) 하이랜드   4.3               신사역 1번 출구 도보 5분•8.7km
# 1   강남 호텔 더 디자이너스 리즈 프리미어   4.6                신논현역 3번출구 도보1분•9.5km
# 2          강남 YAJA 강남 논현점   4.4                  9호선 언주역 4번 출구•10km
# 3                  강남 캠퍼스   4.6               강남역 1번출구 도보 2분•10.3km
# 4                 역삼 소울하다   4.8                              10.4km
# 5                  강남 BNN   4.5                  강남역 2번출구 부근•10.4km
# 6     역삼 Hotel The Artist   4.6               역삼역 8번출구 도보 5분•10.6km
# 7         역삼 H Avenue 역삼점   4.5               역삼역 8번출구 도보 5분•10.6km
# 8                  역삼 리치웰   4.6                역삼역 8번출구 도보5분•10.6km
# 9                역삼 녹스 호텔   4.5                  역삼역 도보 약 5분•10.6km
# 10                 역삼 맨하탄   4.7                   2호선 역삼역 인근•10.6km
# 11           역삼 호텔스타 프리미어   4.6               역삼역 8번출구 도보 5분•10.7km
# 12   역삼 Premier Hotel XYM   4.7              역삼역 1번 출구 도보 5분•10.7km
# ...

# %%
# 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
i = 1
ii = 1
iii = 1
# 지역 인기 추천
while True:    
    try:
        bname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
        bscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
        bloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
        bprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(1) > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(bname.text)
        score_list.append(bscore.text)
        loc_list.append(bloc.text)
        price_list.append(bprice.text)
        i+=1
    except:
        break
# 지역 추천
while True:
    try:
        pname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
        pscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
        ploc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
        pprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(2) > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(pname.text)
        score_list.append(pscore.text)
        loc_list.append(ploc.text)
        price_list.append(pprice.text)
        ii+=1
    except:
        break
# 스페셜
while True:
    try:
        sname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(iii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
        sscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(iii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
        sloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(iii)+') > a > div > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
        sprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child(3) > div > div:nth-child('+str(iii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
        name_list.append(sname.text)
        score_list.append(sscore.text)
        loc_list.append(sloc.text)
        price_list.append(sprice.text)
        iii+=1
    except:
        break
# 베스트

lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)       
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

# %%
###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.PlaceListTabs_active__fi3E1.swiper-slide-active > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2]
pbn_num = [3,4,5]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            rname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            rscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            rloc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            rprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(rname.text)
            score_list.append(rscore.text)
            loc_list.append(rloc.text)
            price_list.append(rprice.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            pname = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            pscore = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            ploc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            pprice = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(pname.text)
            score_list.append(pscore.text)
            loc_list.append(ploc.text)
            price_list.append(pprice.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'h'
time.sleep(1)
