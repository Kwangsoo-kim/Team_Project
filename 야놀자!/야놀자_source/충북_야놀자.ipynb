# %%
import pandas as pd
import requests
import re
import json
import datetime
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
import time
import numpy
pd.set_option('display.max_row', 50000)

# %%
dv = webdriver.Chrome()
dv.get('https://www.yanolja.com/area?')


############################################  충북 카테고리
cb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(7)')
cb.click()
time.sleep(2)
############################################ 충북 -> 흥덕구/서원구
hs = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(1) > span')
hs.click()
time.sleep(2)



############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)

# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)

########### 데이터통합 및 csv
hs = pd.concat([gm,gh])
hs.reset_index(drop=True,inplace=True)
hs['loc'] = hs['loc'].str.replace('•','-')
hs['loc'] = hs['loc'].str.replace('⭐','')
hs['loc'] = hs['loc'].str.replace('❤️','')
hs['loc'] = hs['loc'].str.replace('❤','')
hs['loc'] = hs['loc'].str.replace('💜','')
hs['loc'] = hs['loc'].str.replace('✨','')
hs.to_csv('흥서.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################  충북 카테고리
cb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(7)')
cb.click()
time.sleep(2)
############################################ 충북 -> 상당구/청원구
sc = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(2) > span')
sc.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)

# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)



###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)

########### 데이터통합 및 csv
sc = pd.concat([gm,gh,gf])
sc.reset_index(drop=True,inplace=True)
sc['loc'] = sc['loc'].str.replace('•','-')
sc['loc'] = sc['loc'].str.replace('⭐','')
sc['loc'] = sc['loc'].str.replace('❤️','')
sc['loc'] = sc['loc'].str.replace('❤','')
sc['loc'] = sc['loc'].str.replace('⚡','')
sc['loc'] = sc['loc'].str.replace('★','')
sc.to_csv('상청.csv',sep=',',encoding='cp949')
time.sleep(1)

################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################  충북 카테고리
cb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(7)')
cb.click()
time.sleep(2)
############################################ 충북 -> 충주/수안보
cs = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(3) > span')
cs.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)

# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)



###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==5:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
###################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==3:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'
########### 데이터통합 및 csv
cs = pd.concat([gm,gh,gf,gg])
cs.reset_index(drop=True,inplace=True)
cs['loc'] = cs['loc'].str.replace('•','-')
cs.to_csv('충수.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################  충북 카테고리
cb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(7)')
cb.click()
time.sleep(2)
############################################ 충북 -> 제천/진천/음성/단양
jjud = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(4) > span')
jjud.click()
time.sleep(2)


############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)

# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)



###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==11:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
###################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==3:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
jjud = pd.concat([gm,gh,gf,gg])
jjud.reset_index(drop=True,inplace=True)
jjud['loc'] = jjud['loc'].str.replace('•','-')
jjud.to_csv('제진음단.csv',sep=',',encoding='cp949')
time.sleep(1)


################################################### 뒤로가기
back = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > nav > section > div > div.CollapsingNavTopButtons_backButton__1NQwd')
back.click()
time.sleep(1)
############################################  충북 카테고리
cb = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerLeft__15JpV > div.scroll-content > div > a:nth-child(7)')
cb.click()
time.sleep(2)
############################################ 충북 -> 보은/옥천/괴산/증평/영동
bogjy = dv.find_element_by_css_selector('#__next > div.StyleComponent_container__1jS9A.area_layout__Y0yxY > div > div.LocationPickerBody_locationPickerRight__MQnez > div.scroll-content > div > a:nth-child(5) > span')
bogjy.click()
time.sleep(2)
############################################ 모텔
motel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
motel.click()
time.sleep(2)

# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==6:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 베스트
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_prices__2_1nN > div:nth-child(2) > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gm = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gm=gm.drop_duplicates()
gm.reset_index(drop=True,inplace=True)
gm['category'] = 'm'
time.sleep(1)

################################################################## 호텔
hotel = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(3) > div')
hotel.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==4:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gh = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gh=gh.drop_duplicates()
gh.reset_index(drop=True,inplace=True)
gh['category'] = 'h'
time.sleep(1)



###################### 팬션/풀빌라
pf = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a.swiper-slide.PlaceListTabs_tabs__35lkp.swiper-slide-next > div')
pf.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        time.sleep(1)
        cnt+=1
        if cnt==11:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div:nth-child(1) > div.PlaceListScore_container__2-JXJ.PlaceListItemBanner_score__3HHN5 > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_image__1-YJA > div.PlaceListDistance_containerBanner__2r0mD > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemBanner_contents__1oW8G > div.PlaceListItemBanner_prices__5aywq > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
for li in pbn_num:
    ii = 1
    # 프리미엄
    # 스페셜
    # 일반
    while True:
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(ii)+') > a > div > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            ii+=1
        except:
            break
len(name_list),len(score_list),len(loc_list),len(price_list)
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)  
# 크롤링한 리스트 Dataframe으로
gf = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]})
# 중복행 제거
gf=gf.drop_duplicates()
gf.reset_index(drop=True,inplace=True)
gf['category'] = 'f'
time.sleep(1)
###################################### 게스트하우스
guest = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListTabs_container__1musp.PlaceListTabs_isPc__3o98b > div > div.Swiper_swiper__3NQ_7.Swiper_tab__1opHO > div > div.swiper-wrapper > a:nth-child(5) > div')
guest.click()
time.sleep(2)
# 수량 늘리기
mapp = dv.find_element_by_css_selector('#__next > div:nth-child(1) > header > div > section > div > section.PlaceListSubOptions_container__u_2OV > div > button.PlaceListSubOptions_mapButton__2gVyL > span > svg')
mapp.click()
time.sleep(1)
# 숙소 더보기
try:
    clicks = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PlaceListMap_header__2vYKK > button.PlaceListMap_moreButton__2hIAG')
    cnt = 0
    while True:
        clicks.click()
        cnt+=1
        time.sleep(1)
        if cnt==3:
            break
except:
    print('추가없음')
time.sleep(1)
# 숙소 더보기 나기기
mappexit = dv.find_element_by_css_selector('body > div:nth-child(49) > div > div > div > div > div.PageTitle_container__wVTJI.PageTitle_hasBottomBorder__1vShE.white.PlaceListMap_title__1E5Oq > div > div.PageTitle_leftWrap__1DN6c > div > button > img')
mappexit.click()
time.sleep(1)
# 데이터 크롤링
# 이름 가져오기
soup = BeautifulSoup(dv.page_source,'html.parser')
name_list = []
score_list = []
loc_list = []
price_list= []
r_num = [1,2,3,4,5]
pbn_num = [1,2,3,4,5,6,7]
for li in r_num:
    i = 1
    # 지역 인기추천
    # 지역 추천
    while True:    
        try:
            name = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListTitle_container__qe7XH > strong')
            score = soup.select('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_extraInfos__3Bp2B > div > span.PlaceListScore_rating__3Glxf')
            loc = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_image__2mlnK.place-image > div.PlaceListDistance_containerText__2ODf3 > span')
            price = soup.select_one('#__next > div.StyleComponent_container__1jS9A.list_listContainer__2kL99.list_bottomPadding__xvWzu > section.PlaceListBody_placeListBodyContainer__1u70R > div:nth-child('+str(li)+') > div > div:nth-child('+str(i)+') > a > div.PlaceListItemText_area__3l67D > div.PlaceListItemText_contents__2GR73.place-content.PlaceListItemText_singlePrice__1aj9I > div.PlaceListItemText_prices__2_1nN > div > div.PlacePriceInfo_priceInfo__H0DLi > span.PlacePriceInfo_salePrice__28VZD')
            name_list.append(name.text)
            if len(score)==1:
                 for s in score:
                        score_list.append(s.text)
            else:
                score_list.append('3.5')
            loc_list.append(loc.text)
            price_list.append(price.text)
            i+=1
        except:
            break
lengg = [len(name_list),len(score_list),len(loc_list),len(price_list)]
c=min(lengg)
# 크롤링한 리스트 Dataframe으로
gg = pd.DataFrame({'name':name_list[0:c],
                  'score':score_list[0:c],
                  'loc':loc_list[0:c],
                  'lowest_price':price_list[0:c]},)
# 중복행 제거
gg=gg.drop_duplicates()
gg.reset_index(drop=True,inplace=True)
gg['category'] = 'g'

########### 데이터통합 및 csv
bogjy = pd.concat([gm,gh,gf,gg])
bogjy.reset_index(drop=True,inplace=True)
bogjy['loc'] = bogjy['loc'].str.replace('•','-')
bogjy.to_csv('보옥괴증영.csv',sep=',',encoding='cp949')
time.sleep(1)

dv.close()
