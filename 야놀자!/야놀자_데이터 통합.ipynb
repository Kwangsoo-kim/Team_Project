# %%
import pandas as pd
pd.set_option('display.max_row', 50000)

# %%
#################### 서울 데이터 편집 및 합성
# 1. 강남/역삼/삼성논현
s1 = pd.read_csv('seoul_data/감역삼논.csv',sep=',',encoding='cp949')
s1['loc2'] = '강남/역삼/삼성/논현'
s1['SIG_CD'] = 11680

# 2. 서초/신사/방배
s2 = pd.read_csv('seoul_data/서신방.csv',sep=',',encoding='cp949')
s2['loc2'] = '서초/신사/방배'
s2['SIG_CD'] = 11650
# 3. 잠실/신천
s3 = pd.read_csv('seoul_data/잠실새내.csv',sep=',',encoding='cp949')
s3['loc2'] = '잠실/신천'
s3['SIG_CD'] = 11710
# 4. 영등포/여의도
s4 = pd.read_csv('seoul_data/영여.csv',sep=',',encoding='cp949')
s4['loc2'] = '영등포/여의도'
s4['SIG_CD'] = 11560
# 5. 신림/서울대/사당/동작
s5 = pd.read_csv('seoul_data/신서사동.csv',sep=',',encoding='cp949')
s5['loc2'] = '신림/서울대/사당/동작'
s5['SIG_CD'] = 11620
# 6. 천호/길동/둔촌
s6 = pd.read_csv('seoul_data/천길둔.csv',sep=',',encoding='cp949')
s6['loc2'] = '천호/길동/둔촌'
s6['SIG_CD'] = 11740
# 7. 화곡/까치산/양천/목동
s7 = pd.read_csv('seoul_data/화까양목.csv',sep=',',encoding='cp949')
s7['loc2'] = '화곡/까치산/양천/목동'
s7['SIG_CD'] = 11500
# 8. 구로/금천/오류/신도림
s8 = pd.read_csv('seoul_data/구금오신.csv',sep=',',encoding='cp949')
s8['loc2'] = '구로/금천/오류/신도림'
s8['SIG_CD'] = 11530
# 9. 신촌/홍대/합정
s9 = pd.read_csv('seoul_data/신홍합.csv',sep=',',encoding='cp949')
s9['loc2'] = '신촌/홍대/합정'
s9['SIG_CD'] = 11440
# 10. 연신내/불광/응암
s10= pd.read_csv('seoul_data/연불응.csv',sep=',',encoding='cp949')
s10['loc2'] = '연신내/불광/응암'
s10['SIG_CD'] = 11380
# 11. 종로/대학로/동묘앞역
s11 = pd.read_csv('seoul_data/종대동.csv',sep=',',encoding='cp949')
s11['loc2'] = '종로/대학로/동묘앞역'
s11['SIG_CD'] = 11110
# 12. 성신여대/성북/월곡
s12 = pd.read_csv('seoul_data/성성월.csv',sep=',',encoding='cp949')
s12['loc2'] = '성신여대/성북/월곡'
s12['SIG_CD'] = 11290
# 13. 이태원/용산/서울역/명동/회현
s13 = pd.read_csv('seoul_data/이용서명회.csv',sep=',',encoding='cp949')
s13['loc2'] = '이태원/용산/서울역/명동/회현'
s13['SIG_CD'] = 11170
# 14. 동대문/을지로/충무로/신당/약수
s14 = pd.read_csv('seoul_data/동을충신약.csv',sep=',',encoding='cp949')
s14['loc2'] = '동대문/을지로/충무로/신당/약수'
s14['SIG_CD'] = 11140
# 15. 회기/고려대/청량리/신설동
s15 = pd.read_csv('seoul_data/회고청신.csv',sep=',',encoding='cp949')
s15['loc2'] = '회기/고려대/청량리/신설동'
s15['SIG_CD'] = 11230
# 16. 장안동/답십리
s16 = pd.read_csv('seoul_data/장답.csv',sep=',',encoding='cp949')
s16['loc2'] = '장안동/답십리'
s16['SIG_CD'] = 11230
# 17. 건대/군자/구의
s17 = pd.read_csv('seoul_data/건군구.csv',sep=',',encoding='cp949')
s17['loc2'] = '건대/군자/구의'
s17['SIG_CD'] = 11215
# 18. 왕십리/성수/금호
s18 = pd.read_csv('seoul_data/왕성금.csv',sep=',',encoding='cp949')
s18['loc2'] = '왕십리/성수/금호'
s18['SIG_CD'] = 11200
# 19. 수유/미아
s19 = pd.read_csv('seoul_data/수미.csv',sep=',',encoding='cp949')
s19['loc2'] = '수유/미아'
s19['SIG_CD'] = 11305
# 20. 상봉/중랑/면목
s20 = pd.read_csv('seoul_data/상중면.csv',sep=',',encoding='cp949')
s20['loc2'] = '상봉/중랑/면목'
s20['SIG_CD'] = 11260
# 21. 태릉/노원/도봉/창동
s21 = pd.read_csv('seoul_data/태노도창.csv',sep=',',encoding='cp949')
s21['loc2'] = '태릉/노원/도봉/창동'
s21['SIG_CD'] = 11320

################ concat 및 dtype변경
seoul_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19,s20,s21],ignore_index=True)
seoul_df = seoul_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
seoul_df['lowest_price'] = seoul_df['lowest_price'].str.replace('원','')
seoul_df['lowest_price'] = seoul_df['lowest_price'].str.replace(',','')
avgprice_df = seoul_df[seoul_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
seoul_df['lowest_price'] = seoul_df['lowest_price'].str.replace('예약마감',str(price_avg))
seoul_df['lowest_price'] = seoul_df['lowest_price'].astype(float)
seoul_df.loc[seoul_df['category']=='f','category'] ='p'
seoul_df.to_csv('서울통합.csv',sep=',',encoding='cp949')

# %%
#################### 경기 데이터 편집 및 합성
# 1. 수원 인계/권선/영통
s1 = pd.read_csv('kyunggi_data/수인권영.csv',sep=',',encoding='cp949')
s1['loc2'] = '수원 인계/권선/영통'
s1['SIG_CD']= 41113
# 2. 수원역/구운/장안/세류
s2 = pd.read_csv('kyunggi_data/수구장세.csv',sep=',',encoding='cp949')
s2['loc2'] = '수원역/구운/장안/세류'
s2['SIG_CD']= 41111
# 3. 안양/평촌/인덕원/과천
s3 = pd.read_csv('kyunggi_data/안평인과.csv',sep=',',encoding='cp949')
s3['loc2'] = '안양/평촌/인덕원/과천'
s3['SIG_CD']= 41171
# 4. 성남/분당/위례
s4 = pd.read_csv('kyunggi_data/성분위.csv',sep=',',encoding='cp949')
s4['loc2'] = '성남/분당/위례'
s4['SIG_CD']= 41131
# 5. 용인
s5 = pd.read_csv('kyunggi_data/용인.csv',sep=',',encoding='cp949')
s5['loc2'] = '용인'
s5['SIG_CD']= 41461
# 6. 동탄/화성/오산/병점
s6 = pd.read_csv('kyunggi_data/동화오병.csv',sep=',',encoding='cp949')
s6['loc2'] = '동탄/화성/오산/병점'
s6['SIG_CD']= 41590
# 7. 하남/광주/여주/이천
s7 = pd.read_csv('kyunggi_data/하광여이.csv',sep=',',encoding='cp949')
s7['loc2'] = '하남/광주/여주/이천'
s7['SIG_CD']=41450
# 8. 안산
s8 = pd.read_csv('kyunggi_data/안산.csv',sep=',',encoding='cp949')
s8['loc2'] = '안산'
s8['SIG_CD']= 41271
# 9. 군포/의왕/금정/산본
s9 = pd.read_csv('kyunggi_data/군의금산.csv',sep=',',encoding='cp949')
s9['loc2'] = '군포/의왕/금정/산본'
s9['SIG_CD']= 41410
# 10. 시흥
s10= pd.read_csv('kyunggi_data/시흥.csv',sep=',',encoding='cp949')
s10['loc2'] = '시흥'
s10['SIG_CD']= 41390
# 11. 광명
s11 = pd.read_csv('kyunggi_data/광명.csv',sep=',',encoding='cp949')
s11['loc2'] = '광명'
s11['SIG_CD']= 41210
# 12. 평택/송탄/안성
s12 = pd.read_csv('kyunggi_data/평송안.csv',sep=',',encoding='cp949')
s12['loc2'] = '평택/송탄/안성'
s12['SIG_CD']= 41220
# 13. 부천
s13 = pd.read_csv('kyunggi_data/부천.csv',sep=',',encoding='cp949')
s13['loc2'] = '부천'
s13['SIG_CD']= 41190
# 14. 일산/고양
s14 = pd.read_csv('kyunggi_data/일고.csv',sep=',',encoding='cp949')
s14['loc2'] = '일산/고양'
s14['SIG_CD']=41281
# 15. 파주
s15 = pd.read_csv('kyunggi_data/파주.csv',sep=',',encoding='cp949')
s15['loc2'] = '파주'
s15['SIG_CD']=41480
# 16. 김포
s16 = pd.read_csv('kyunggi_data/김포.csv',sep=',',encoding='cp949')
s16['loc2'] = '김포'
s16['SIG_CD']= 41570
# 17. 의정부
s17 = pd.read_csv('kyunggi_data/의정부.csv',sep=',',encoding='cp949')
s17['loc2'] = '의정부'
s17['SIG_CD']= 41150
# 18. 구리
s18 = pd.read_csv('kyunggi_data/구리.csv',sep=',',encoding='cp949')
s18['loc2'] = '구리'
s18['SIG_CD']= 41310
# 19. 남양주
s19 = pd.read_csv('kyunggi_data/남양주.csv',sep=',',encoding='cp949')
s19['loc2'] = '남양주'
s19['SIG_CD']= 41360
# 20. 포천
s20 = pd.read_csv('kyunggi_data/포천.csv',sep=',',encoding='cp949')
s20['loc2'] = '포천'
s20['SIG_CD']= 41650
# 21. 양주/동두천/연천
s21 = pd.read_csv('kyunggi_data/양동연.csv',sep=',',encoding='cp949')
s21['loc2'] = '양주/동두천/연천'
s21['SIG_CD']= 41630
# 22. 양평
s22 = pd.read_csv('kyunggi_data/양평.csv',sep=',',encoding='cp949')
s22['loc2'] = '양평'
s22['SIG_CD']= 41830
# 23. 가평/청평
s23 = pd.read_csv('kyunggi_data/가청.csv',sep=',',encoding='cp949')
s23['loc2'] = '가평/청평'
s23['SIG_CD']= 41820
# 24. 제부도/대부도
s24 = pd.read_csv('kyunggi_data/제대.csv',sep=',',encoding='cp949')
s24['loc2'] = '제부도/대부도'
s24['SIG_CD']= 41271
################ concat 및 dtype변경
kyunggi_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19,s20,s21,s22,s23,s24],ignore_index=True)
kyunggi_df = kyunggi_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
kyunggi_df['lowest_price'] = kyunggi_df['lowest_price'].str.replace('원','')
kyunggi_df['lowest_price'] = kyunggi_df['lowest_price'].str.replace(',','')
avgprice_df = kyunggi_df[kyunggi_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
kyunggi_df['lowest_price'] = kyunggi_df['lowest_price'].str.replace('예약마감',str(price_avg))
kyunggi_df['lowest_price'] = kyunggi_df['lowest_price'].astype(float)
kyunggi_df.loc[kyunggi_df['category']=='f','category'] ='p'
kyunggi_df.to_csv('경기통합.csv',sep=',',encoding='cp949')

# %%
#################### 인천 데이터 편집 및 합성
# 1. 부평
s1 = pd.read_csv('inchen_data/부평.csv',sep=',',encoding='cp949')
s1['loc2'] = '부평'
s1['SIG_CD'] = 28237
# 2. 구월
s2 = pd.read_csv('inchen_data/구월.csv',sep=',',encoding='cp949')
s2['loc2'] = '구월'
s2['SIG_CD'] = 28200
# 3. 서구
s3 = pd.read_csv('inchen_data/서구.csv',sep=',',encoding='cp949')
s3['loc2'] = '서구'
s3['SIG_CD'] = 28260
# 4. 계양
s4 = pd.read_csv('inchen_data/계양.csv',sep=',',encoding='cp949')
s4['loc2'] = '계양'
s4['SIG_CD'] = 28245
# 5. 주안
s5 = pd.read_csv('inchen_data/주안.csv',sep=',',encoding='cp949')
s5['loc2'] = '주안'
s5['SIG_CD'] = 28177
# 6. 송도/연수
s6 = pd.read_csv('inchen_data/송연.csv',sep=',',encoding='cp949')
s6['loc2'] = '송도/연수'
s6['SIG_CD'] = 28185
# 7. 인천공항/을왕리
s7 = pd.read_csv('inchen_data/인을.csv',sep=',',encoding='cp949')
s7['loc2'] = '인천공항/을왕리'
s7['SIG_CD'] = 28110
# 8. 중구
s8 = pd.read_csv('inchen_data/중구.csv',sep=',',encoding='cp949')
s8['loc2'] = '중구'
s8['SIG_CD'] = 28110
# 9. 강화/옹진
s9 = pd.read_csv('inchen_data/강옹.csv',sep=',',encoding='cp949')
s9['loc2'] = '강화/옹진'
s9['SIG_CD'] = 28710
# 10. 동암/간석
s10= pd.read_csv('inchen_data/동간.csv',sep=',',encoding='cp949')
s10['loc2'] = '동암/간석'
s10['SIG_CD'] = 28200
# 11. 남동구
s11 = pd.read_csv('inchen_data/남동구.csv',sep=',',encoding='cp949')
s11['loc2'] = '남동구'
s11['SIG_CD'] = 28200
# 12. 용현/숭의/도화/동구
s12 = pd.read_csv('inchen_data/용숭도동.csv',sep=',',encoding='cp949')
s12['loc2'] = '용현/숭의/도화/동구'
s12['SIG_CD'] = 28140
################ concat 및 dtype변경
incheon_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12],ignore_index=True)
incheon_df = incheon_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
incheon_df['lowest_price'] = incheon_df['lowest_price'].str.replace('원','')
incheon_df['lowest_price'] = incheon_df['lowest_price'].str.replace(',','')
avgprice_df = incheon_df[incheon_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
incheon_df['lowest_price'] = incheon_df['lowest_price'].str.replace('예약마감',str(price_avg))
incheon_df['lowest_price'] = incheon_df['lowest_price'].astype(float)
incheon_df.loc[incheon_df['category']=='f','category'] ='p'
incheon_df.to_csv('인천통합.csv',sep=',',encoding='cp949')

# %%
#################### 강원 데이터 편집 및 합성
# 1. 춘천/강촌
s1 = pd.read_csv('gangwon_data/춘강.csv',sep=',',encoding='cp949')
s1['loc2'] = '춘천/강촌'
s1['SIG_CD'] = '42110'
# 2. 원주
s2 = pd.read_csv('gangwon_data/원주.csv',sep=',',encoding='cp949')
s2['loc2'] = '원주'
s2['SIG_CD'] = '42130'
# 3. 경포대/사천/주문진/정동진
s3 = pd.read_csv('gangwon_data/경사주정.csv',sep=',',encoding='cp949')
s3['loc2'] = '경포대/사천/주문진/정동진'
s3['SIG_CD'] = '42150'
# 4. 강릉역/교동/옥계
s4 = pd.read_csv('gangwon_data/강교옥.csv',sep=',',encoding='cp949')
s4['loc2'] = '강릉역/교동/옥계'
s4['SIG_CD'] = '42111'
# 5. 영월/정선
s5 = pd.read_csv('gangwon_data/영정.csv',sep=',',encoding='cp949')
s5['loc2'] = '영월/정선'
s5['SIG_CD'] = '42750'
# 6. 속초/고성
s6 = pd.read_csv('gangwon_data/속고.csv',sep=',',encoding='cp949')
s6['loc2'] = '속초/고성'
s6['SIG_CD'] = '42820'
# 7. 양양
s7 = pd.read_csv('gangwon_data/양양.csv',sep=',',encoding='cp949')
s7['loc2'] = '양양'
s7['SIG_CD'] = '42830'
# 8. 동해척/태백
s8 = pd.read_csv('gangwon_data/동삼태.csv',sep=',',encoding='cp949')
s8['loc2'] = '동해/삼척/태백'
s8['SIG_CD'] = '42230'
# 9. 평창
s9 = pd.read_csv('gangwon_data/평창.csv',sep=',',encoding='cp949')
s9['loc2'] = '평창'
s9['SIG_CD'] = '42760'
# 10. 홍천/횡성
s10= pd.read_csv('gangwon_data/홍횡.csv',sep=',',encoding='cp949')
s10['loc2'] = '홍천/횡성'
s10['SIG_CD'] = '42720'
# 11. 화천/철원/인제/양구
s11 = pd.read_csv('gangwon_data/화철인양.csv',sep=',',encoding='cp949')
s11['loc2'] = '화천/철원/인제/양구'
s11['SIG_CD'] = '42810'
################ concat 및 dtype변경
gangwon_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11],ignore_index=True)
gangwon_df = gangwon_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
gangwon_df['lowest_price'] = gangwon_df['lowest_price'].str.replace('원','')
gangwon_df['lowest_price'] = gangwon_df['lowest_price'].str.replace(',','')
avgprice_df = gangwon_df[gangwon_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
gangwon_df['lowest_price'] = gangwon_df['lowest_price'].str.replace('예약마감',str(price_avg))
gangwon_df['lowest_price'] = gangwon_df['lowest_price'].astype(float)
gangwon_df.loc[gangwon_df['category']=='f','category'] ='p'
gangwon_df.to_csv('강원통합.csv',sep=',',encoding='cp949')

# %%
#################### 제주 데이터 편집 및 합성
# 1. 제주시
s1 = pd.read_csv('jeju_data/제주시.csv',sep=',',encoding='cp949')
s1['loc2'] = '제주시'
s1['SIG_CD'] = 50110
# 2. 서귀포시
s2 = pd.read_csv('jeju_data/서귀포.csv',sep=',',encoding='cp949')
s2['loc2'] = '서귀포시'
s2['SIG_CD'] = 50130
# 3. 하귀/애월/한림/협재
s3 = pd.read_csv('jeju_data/하애한협.csv',sep=',',encoding='cp949')
s3['loc2'] = '하귀/애월한림/협재'
s3['SIG_CD'] = 50110
################ concat 및 dtype변경
jeju_df = pd.concat([s1,s2,s3],ignore_index=True)
jeju_df = jeju_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
jeju_df['lowest_price'] = jeju_df['lowest_price'].str.replace('원','')
jeju_df['lowest_price'] = jeju_df['lowest_price'].str.replace(',','')
avgprice_df = jeju_df[jeju_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
jeju_df['lowest_price'] = jeju_df['lowest_price'].str.replace('예약마감',str(price_avg))
jeju_df['lowest_price'] = jeju_df['lowest_price'].astype(float)
jeju_df.loc[jeju_df['category']=='f','category'] ='p'
jeju_df.to_csv('제주통합.csv',sep=',',encoding='cp949')

# %%
#################### 대전 데이터 편집 및 합성
# 1. 유성구
s1 = pd.read_csv('daejeon_data/유성구.csv',sep=',',encoding='cp949')
s1['loc2'] = '유성구'
s1['SIG_CD'] = 30200
# 2. 중구
s2 = pd.read_csv('daejeon_data/중구.csv',sep=',',encoding='cp949')
s2['loc2'] = '대전중구'
s2['SIG_CD'] = 30140
# 3. 동구
s3 = pd.read_csv('daejeon_data/동구.csv',sep=',',encoding='cp949')
s3['loc2'] = '대전동구'
s3['SIG_CD'] = 30110
# 4. 서구
s4 = pd.read_csv('daejeon_data/서구.csv',sep=',',encoding='cp949')
s4['loc2'] = '대전서구'
s4['SIG_CD'] = 30170
# 5. 대덕구
s5 = pd.read_csv('daejeon_data/대덕구.csv',sep=',',encoding='cp949')
s5['loc2'] = '대덕구'
s5['SIG_CD'] = 30230
################ concat 및 dtype변경
daejeon_df = pd.concat([s1,s2,s3,s4,s5],ignore_index=True)
daejeon_df = daejeon_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
daejeon_df['lowest_price'] = daejeon_df['lowest_price'].str.replace('원','')
daejeon_df['lowest_price'] = daejeon_df['lowest_price'].str.replace(',','')
avgprice_df = daejeon_df[daejeon_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
daejeon_df['lowest_price'] = daejeon_df['lowest_price'].str.replace('예약마감',str(price_avg))
daejeon_df['lowest_price'] = daejeon_df['lowest_price'].astype(float)
daejeon_df.loc[daejeon_df['category']=='f','category'] ='p'
daejeon_df.to_csv('대전통합.csv',sep=',',encoding='cp949')

# %%
#################### 충북 데이터 편집 및 합성
# 1. 청주 흥덕구/서원구
s1 = pd.read_csv('choongbuk_data/흥서.csv',sep=',',encoding='cp949')
s1['loc2'] = '청주 흥덕구/서원구'
s1['SIG_CD'] = 43112
# 2. 청주 상당구/청원구
s2 = pd.read_csv('choongbuk_data/상청.csv',sep=',',encoding='cp949')
s2['loc2'] = '청주 상당구/청원구'
s2['SIG_CD'] = 43111
# 3. 충주/수안보
s3 = pd.read_csv('choongbuk_data/충수.csv',sep=',',encoding='cp949')
s3['loc2'] = '충주/수안보'
s3['SIG_CD'] = 43130
# 4. 제천/진천/음성/단양
s4 = pd.read_csv('choongbuk_data/제진음단.csv',sep=',',encoding='cp949')
s4['loc2'] = '제천/진천/음성/단양'
s4['SIG_CD'] = 43150
# 5. 보은/옥천/괴산/증평/영동
s5 = pd.read_csv('choongbuk_data/보옥괴증영.csv',sep=',',encoding='cp949')
s5['loc2'] = '보은/옥천/괴산/증평/영동'
s5['SIG_CD'] = 43720
################ concat 및 dtype변경
choongbuk_df = pd.concat([s1,s2,s3,s4,s5],ignore_index=True)
choongbuk_df = choongbuk_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
choongbuk_df['lowest_price'] = choongbuk_df['lowest_price'].str.replace('원','')
choongbuk_df['lowest_price'] = choongbuk_df['lowest_price'].str.replace(',','')
avgprice_df = choongbuk_df[choongbuk_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
choongbuk_df['lowest_price'] = choongbuk_df['lowest_price'].str.replace('예약마감',str(price_avg))
choongbuk_df['lowest_price'] = choongbuk_df['lowest_price'].astype(float)
choongbuk_df.loc[choongbuk_df['category']=='f','category'] ='p'
choongbuk_df.to_csv('충북통합.csv',sep=',',encoding='cp949')

# %%
#################### 충남 데이터 편집 및 합성
# 1. 천안 서북구
s1 = pd.read_csv('choongnam_data/천안서북구.csv',sep=',',encoding='cp949')
s1['loc2'] = '천안 서북구'
s1['SIG_CD'] = 44133
# 2. 천안 동남구
s2 = pd.read_csv('choongnam_data/천안 동남구.csv',sep=',',encoding='cp949')
s2['loc2'] = '천안 동남구'
s2['SIG_CD'] = 44131
# 3. 아산
s3 = pd.read_csv('choongnam_data/아산.csv',sep=',',encoding='cp949')
s3['loc2'] = '아산'
s3['SIG_CD'] = 44200
# 4. 공주/동학사/세종
s4 = pd.read_csv('choongnam_data/공동세종.csv',sep=',',encoding='cp949')
s4['loc2'] = '공주/동학사/세종'
s4['SIG_CD'] = 44150
# 5. 계룡/금산/논산/청양
s5 = pd.read_csv('choongnam_data/계금논청.csv',sep=',',encoding='cp949')
s5['loc2'] = '계룡/금산/논산/청양'
s5['SIG_CD'] = 44230
# 6. 예산/홍성
s6 = pd.read_csv('choongnam_data/예홍.csv',sep=',',encoding='cp949')
s6['loc2'] = '예산/홍성'
s6['SIG_CD'] = 44800
# 7. 태안/안면도/서산
s7 = pd.read_csv('choongnam_data/태안서.csv',sep=',',encoding='cp949')
s7['loc2'] = '태안/안면도/서산'
s7['SIG_CD'] = 44825
# 8. 당진
s8 = pd.read_csv('choongnam_data/당진.csv',sep=',',encoding='cp949')
s8['loc2'] = '당진'
s8['SIG_CD'] = 44270
# 9. 보령/대천해수욕장
s9 = pd.read_csv('choongnam_data/보대.csv',sep=',',encoding='cp949')
s9['loc2'] = '보령/대천해수욕장'
s9['SIG_CD'] = 44180
# 10. 서천/부여
s10 = pd.read_csv('choongnam_data/서부.csv',sep=',',encoding='cp949')
s10['loc2'] = '서천/부여'
s10['SIG_CD'] = 44760
################ concat 및 dtype변경
choongnam_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10],ignore_index=True)
choongnam_df = choongnam_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
choongnam_df['lowest_price'] = choongnam_df['lowest_price'].str.replace('원','')
choongnam_df['lowest_price'] = choongnam_df['lowest_price'].str.replace(',','')
avgprice_df = choongnam_df[choongnam_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
choongnam_df['lowest_price'] = choongnam_df['lowest_price'].str.replace('예약마감',str(price_avg))
choongnam_df['lowest_price'] = choongnam_df['lowest_price'].astype(float)
choongnam_df.loc[choongnam_df['category']=='f','category'] ='p'
choongnam_df.to_csv('충남통합.csv',sep=',',encoding='cp949')

# %%
#################### 부산 데이터 편집 및 합성
# 1. 해운대/센텀시티/재송
s1 = pd.read_csv('busan_data/해운센텀재송.csv',sep=',',encoding='utf8')
s1['SIG_CD'] = 26350
# 2. 송정/기장/정관
s2 = pd.read_csv('busan_data/송기정.csv',sep=',',encoding='cp949')
s2['SIG_CD'] = 26710
# 3. 광안리/수영
s3 = pd.read_csv('busan_data/광안리수영.csv',sep=',',encoding='cp949')
s3['SIG_CD'] = 26500
# 4. 경성대/대연/용호동/문현
s4 = pd.read_csv('busan_data/경대용문.csv',sep=',',encoding='cp949')
s4['SIG_CD'] = 26290
# 5. 서면/양정/초읍/부산시민공원
s5 = pd.read_csv('busan_data/서양초부.csv',sep=',',encoding='cp949')
s5['SIG_CD'] = 26230
# 6. 남포동/중앙동/태종대/송도/영도
s6 = pd.read_csv('busan_data/남중태송영.csv',sep=',',encoding='cp949')
s6['SIG_CD'] = 26110
# 7. 부산역/범일동/부산진역
s7 = pd.read_csv('busan_data/부범부.csv',sep=',',encoding='utf8')
s7['SIG_CD'] = 26170
# 8. 연산/토곡
s8 = pd.read_csv('busan_data/연토.csv',sep=',',encoding='utf8')
s8['SIG_CD'] = 26470
# 9. 동래/사직/온천장/부산대/구서
s9 = pd.read_csv('busan_data/동래사직온천장부산대구서.csv',sep=',',encoding='cp949')
s9['SIG_CD'] = 26260
# 10. 사상/엄궁/학장
s10 = pd.read_csv('busan_data/사엄학.csv',sep=',',encoding='cp949')
s10['SIG_CD'] = 26530
# 11. 덕천/화명/만덕/구포
s11 = pd.read_csv('busan_data/덕화만구.csv',sep=',',encoding='utf8')
s11['SIG_CD'] = 26320
# 12. 하단/명지/김해공항/다대포/강서/신호/괴정/지사
s12 = pd.read_csv('busan_data/하명김다강신괴지.csv',sep=',',encoding='cp949')
s12['SIG_CD'] = 26380
################ concat 및 dtype변경
busan_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12],ignore_index=True)
busan_df = busan_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
busan_df['lowest_price'] = busan_df['lowest_price'].str.replace('원','')
busan_df['lowest_price'] = busan_df['lowest_price'].str.replace(',','')
avgprice_df = busan_df[busan_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
busan_df['lowest_price'] = busan_df['lowest_price'].str.replace('예약마감',str(price_avg))
busan_df['lowest_price'] = busan_df['lowest_price'].astype(float)
busan_df.loc[busan_df['category']=='f','category'] ='p'
busan_df.to_csv('부산통합.csv',sep=',',encoding='utf8')

# %%
#################### 울산 데이터 편집 및 합성
# 1. 남구/중구
s1 = pd.read_csv('ulsan_data/남구중구.csv',sep=',',encoding='cp949')
s1['SIG_CD'] = 31110
# 2. 동구/북구/울주군
s2 = pd.read_csv('ulsan_data/동북울.csv',sep=',',encoding='cp949')
s2['SIG_CD'] = 31170
################ concat 및 dtype변경
ulsan_df = pd.concat([s1,s2],ignore_index=True)
ulsan_df = ulsan_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
ulsan_df['lowest_price'] = ulsan_df['lowest_price'].str.replace('원','')
ulsan_df['lowest_price'] = ulsan_df['lowest_price'].str.replace(',','')
avgprice_df = ulsan_df[ulsan_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
ulsan_df['lowest_price'] = ulsan_df['lowest_price'].str.replace('예약마감',str(price_avg))
ulsan_df['lowest_price'] = ulsan_df['lowest_price'].astype(float)
ulsan_df.loc[ulsan_df['category']=='f','category'] ='p'
ulsan_df.to_csv('울산통합.csv',sep=',',encoding='cp949')

# %%
#################### 경남 데이터 편집 및 합성
# 1. 창원 상남동/용호동/중앙동/창원시청
s1 = pd.read_csv('gyeongnam_data/상용중창.csv',sep=',',encoding='cp949')
s1['SIG_CD'] = 48125
# 2. 창원 명서동/봉곡동/팔용동/북면온천/창원종합버스터미널
s2 = pd.read_csv('gyeongnam_data/명봉팔북창.csv',sep=',',encoding='cp949')
s2['SIG_CD'] = 48121
# 3. 마산/진해
s3 = pd.read_csv('gyeongnam_data/마산진해.csv',sep=',',encoding='cp949')
s3['SIG_CD'] = 48127
# 4. 김해/장유
s4 = pd.read_csv('gyeongnam_data/김해장유.csv',sep=',',encoding='utf8')
s4['SIG_CD'] = 48250
# 5. 양산/밀양
s5 = pd.read_csv('gyeongnam_data/양산밀양.csv',sep=',',encoding='utf8')
s5['SIG_CD'] = 48270
# 6. 진주
s6 = pd.read_csv('gyeongnam_data/진주.csv',sep=',',encoding='utf8')
s6['SIG_CD'] = 48170
# 7. 거제/통영/고성
s7 = pd.read_csv('gyeongnam_data/거통고.csv',sep=',',encoding='cp949')
s7['SIG_CD'] = 48220
# 8. 사천/남해
s8 = pd.read_csv('gyeongnam_data/사천남해.csv',sep=',',encoding='cp949')
s8['SIG_CD'] = 48240
# 9. 하동/산청/함양
s9 = pd.read_csv('gyeongnam_data/하산함.csv',sep=',',encoding='cp949')
s9['SIG_CD'] = 48850
# 10. 거창/함안/창녕/합천/의령
s10 = pd.read_csv('gyeongnam_data/거함창합의.csv',sep=',',encoding='cp949')
s10['SIG_CD'] = 48720
################ concat 및 dtype변경
gyeongnam_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10],ignore_index=True)
gyeongnam_df = gyeongnam_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
gyeongnam_df['lowest_price'] = gyeongnam_df['lowest_price'].str.replace('원','')
gyeongnam_df['lowest_price'] = gyeongnam_df['lowest_price'].str.replace(',','')
avgprice_df = gyeongnam_df[gyeongnam_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
gyeongnam_df['lowest_price'] = gyeongnam_df['lowest_price'].str.replace('예약마감',str(price_avg))
gyeongnam_df['lowest_price'] = gyeongnam_df['lowest_price'].astype(float)
gyeongnam_df.loc[gyeongnam_df['category']=='f','category'] ='p'
gyeongnam_df.to_csv('경남통합.csv',sep=',',encoding='utf8')

# %%
#################### 대구 데이터 편집 및 합성
# 1. 동성로/서문시장/대구시청/삼덕동/교동/종로
s1 = pd.read_csv('daegu_data/동서대삼교종.csv',sep=',',encoding='utf8')
s1['SIG_CD'] = 27110
# 2. 대구역/칠성시장/경북대/엑스코/칠곡지구/태전동/금호지구
s2 = pd.read_csv('daegu_data/대칠경엑칠태금.csv',sep=',',encoding='cp949')
s2['SIG_CD'] = 27230
# 3. 동대구역/고속버스터미널/신천동/신암동
s3 = pd.read_csv('daegu_data/동고신신.csv',sep=',',encoding='utf8')
s3['SIG_CD'] = 27140
# 4. 대구공항/혁신도시/동촌유원지/팔공산/이시아폴리스
s4 = pd.read_csv('daegu_data/대혁동팔이.csv',sep=',',encoding='utf8')
s4['SIG_CD'] = 27140
# 5. 수성못/범어/라이온즈파크/월드컵경기장/앞산공원/대명동/봉덕동
s5 = pd.read_csv('daegu_data/수범라월앞대봉.csv',sep=',',encoding='utf8')
s5['SIG_CD'] = 27260
# 6. 북부정류장/이현공단/평리동/내당동/비산동/원대동
s6 = pd.read_csv('daegu_data/북이평내비원.csv',sep=',',encoding='cp949')
s6['SIG_CD'] =27170
# 7. 두류공원/이월드/광장코아/서부정류장/본리동/죽전동
s7 = pd.read_csv('daegu_data/두이광서본죽.csv',sep=',',encoding='utf8')
s7['SIG_CD'] = 27290
# 8. 성서/계명대/성서공단/상인동/달성군/가창/현풍/논공
s8 = pd.read_csv('daegu_data/성계성상달가현논.csv',sep=',',encoding='cp949')
s8['SIG_CD'] =27710
################ concat 및 dtype변경
daegu_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8],ignore_index=True)
daegu_df = daegu_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
daegu_df['lowest_price'] = daegu_df['lowest_price'].str.replace('원','')
daegu_df['lowest_price'] = daegu_df['lowest_price'].str.replace(',','')
avgprice_df = daegu_df[daegu_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
daegu_df['lowest_price'] = daegu_df['lowest_price'].str.replace('예약마감',str(price_avg))
daegu_df['lowest_price'] = daegu_df['lowest_price'].astype(float)
daegu_df.loc[daegu_df['category']=='f','category'] ='p'
daegu_df.to_csv('대구통합.csv',sep=',',encoding='utf8')

# %%
#################### 경북 데이터 편집 및 합성
# 1. 포항/남구
s1 = pd.read_csv('gyeongbuk_data/포항남구.csv',sep=',',encoding='cp949')
s1['SIG_CD']= 47111
# 2. 포항/북구
s2 = pd.read_csv('gyeongbuk_data/포항북구.csv',sep=',',encoding='utf8')
s2['SIG_CD']= 47113
# 3. 경주
s3 = pd.read_csv('gyeongbuk_data/경주.csv',sep=',',encoding='utf8')
s3['SIG_CD']= 47130
# 4. 구미
s4 = pd.read_csv('gyeongbuk_data/구미.csv',sep=',',encoding='cp949')
s4['SIG_CD']= 47190
# 5. 경산
s5 = pd.read_csv('gyeongbuk_data/경산.csv',sep=',',encoding='cp949')
s5['SIG_CD']= 47290
# 6. 안동
s6 = pd.read_csv('gyeongbuk_data/안동.csv',sep=',',encoding='cp949')
s6['SIG_CD']= 47170
# 7. 영천/청도
s7 = pd.read_csv('gyeongbuk_data/영천청도.csv',sep=',',encoding='cp949')
s7['SIG_CD']= 47230
# 8. 김천/칠곡/성주
s8 = pd.read_csv('gyeongbuk_data/김천칠곡성주.csv',sep=',',encoding='cp949')
s8['SIG_CD']= 47150
# 9. 문경/상주/영주/예천/군위/의성/봉회
s9 = pd.read_csv('gyeongbuk_data/문상영예군의봉.csv',sep=',',encoding='cp949')
s9['SIG_CD']= 47210
# 10. 울진/영덕/청송
s10 = pd.read_csv('gyeongbuk_data/울영청.csv',sep=',',encoding='utf8')
s10['SIG_CD']= 47750
# 11. 울릉도
s11 = pd.read_csv('gyeongbuk_data/울릉도.csv',sep=',',encoding='cp949')
s11['SIG_CD']= 47940
################ concat 및 dtype변경
gyeongbuk_df = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11],ignore_index=True)
gyeongbuk_df = gyeongbuk_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
gyeongbuk_df['lowest_price'] = gyeongbuk_df['lowest_price'].str.replace('원','')
gyeongbuk_df['lowest_price'] = gyeongbuk_df['lowest_price'].str.replace(',','')
avgprice_df = gyeongbuk_df[gyeongbuk_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
gyeongbuk_df['lowest_price'] = gyeongbuk_df['lowest_price'].str.replace('예약마감',str(price_avg))
gyeongbuk_df['lowest_price'] = gyeongbuk_df['lowest_price'].astype(float)
gyeongbuk_df.loc[gyeongbuk_df['category']=='f','category'] ='p'
gyeongbuk_df.to_csv('경북통합.csv',sep=',',encoding='utf8')

# %%
#################### 광주 데이터 편집 및 합성
# 1. 상무지구/금호지구/유스퀘어/서구
s1 = pd.read_csv('gwangju_data/상금유서.csv',sep=',',encoding='cp949')
s1['SIG_CD'] = 29140
# 2. 첨단지구/하남지구/송정역/광산구
s2 = pd.read_csv('gwangju_data/첨하송광.csv',sep=',',encoding='cp949')
s2['SIG_CD'] = 29200
# 3. 충장로/대인시장/국립아시아문화전당/동구/남구
s3 = pd.read_csv('gwangju_data/충대국동남.csv',sep=',',encoding='cp949')
s3['SIG_CD'] = 29110
# 4. 광주역/기아챔피언스필드/전대사거리/북구
s4 = pd.read_csv('gwangju_data/광기전북.csv',sep=',',encoding='cp949')
s4['SIG_CD'] = 29170
################ concat 및 dtype변경
gwangju_df = pd.concat([s1,s2,s3,s4],ignore_index=True)
gwangju_df = gwangju_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
gwangju_df['lowest_price'] = gwangju_df['lowest_price'].str.replace('원','')
gwangju_df['lowest_price'] = gwangju_df['lowest_price'].str.replace(',','')
avgprice_df = gwangju_df[gwangju_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
gwangju_df['lowest_price'] = gwangju_df['lowest_price'].str.replace('예약마감',str(price_avg))
gwangju_df['lowest_price'] = gwangju_df['lowest_price'].astype(float)
gwangju_df.loc[gwangju_df['category']=='f','category'] ='p'
gwangju_df.to_csv('광주통합.csv',sep=',',encoding='cp949')

# %%
#################### 전남 데이터 편집 및 합성
# 1. 여수
s1 = pd.read_csv('jeonnam_data/여수.csv',sep=',',encoding='cp949')
s1['SIG_CD']= 46130
# 2. 순천
s2 = pd.read_csv('jeonnam_data/순천.csv',sep=',',encoding='utf8')
s2['SIG_CD']= 46150
# 3. 광양
s3 = pd.read_csv('jeonnam_data/광양.csv',sep=',',encoding='cp949')
s3['SIG_CD']= 46230
# 4. 목포/무안/영암/신안
s4 = pd.read_csv('jeonnam_data/목무영신.csv',sep=',',encoding='cp949')
s4['SIG_CD']= 46110
# 5. 나주/함평/영광/장성
s5 = pd.read_csv('jeonnam_data/나함영장.csv',sep=',',encoding='cp949')
s5['SIG_CD']= 46170
# 6. 담양/곡성/화순/구례
s6 = pd.read_csv('jeonnam_data/담곡화구.csv',sep=',',encoding='cp949')
s6['SIG_CD']= 46710
# 7. 해남/완도/진도/강진/장흥/보성/고흥
s7 = pd.read_csv('jeonnam_data/해완진강장보고.csv',sep=',',encoding='cp949')
s7['SIG_CD']= 46770
################ concat 및 dtype변경
jeonnam_df = pd.concat([s1,s2,s3,s4,s5,s6,s7],ignore_index=True)
jeonnam_df = jeonnam_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
jeonnam_df['lowest_price'] = jeonnam_df['lowest_price'].str.replace('원','')
jeonnam_df['lowest_price'] = jeonnam_df['lowest_price'].str.replace(',','')
avgprice_df = jeonnam_df[jeonnam_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
jeonnam_df['lowest_price'] = jeonnam_df['lowest_price'].str.replace('예약마감',str(price_avg))
jeonnam_df['lowest_price'] = jeonnam_df['lowest_price'].astype(float)
jeonnam_df.loc[jeonnam_df['category']=='f','category'] ='p'
jeonnam_df.to_csv('전남통합.csv',sep=',',encoding='utf8')

# %%
#################### 전북 데이터 편집 및 합성
# 1. 전주 덕진구
s1 = pd.read_csv('jeonbuk_data/전주덕진구.csv',sep=',',encoding='cp949')
s1['SIG_CD']= 45113
# 2. 전주 완산구/완주
s2 = pd.read_csv('jeonbuk_data/전주완산구완주.csv',sep=',',encoding='cp949')
s2['SIG_CD']= 45111
# 3. 군산
s3 = pd.read_csv('jeonbuk_data/군산.csv',sep=',',encoding='cp949')
s3['SIG_CD']= 45130
# 4. 익산
s4 = pd.read_csv('jeonbuk_data/익산.csv',sep=',',encoding='cp949')
s4['SIG_CD']= 45140
# 5. 남원/임실/순창/무주/진안/장수
s5 = pd.read_csv('jeonbuk_data/남임순무진장.csv',sep=',',encoding='cp949')
s5['SIG_CD']= 45190
# 6. 정읍/부안/김제/고창
s6 = pd.read_csv('jeonbuk_data/정부김고.csv',sep=',',encoding='cp949')
s6['SIG_CD']= 45180
################ concat 및 dtype변경
jeonbuk_df = pd.concat([s1,s2,s3,s4,s5,s6],ignore_index=True)
jeonbuk_df = jeonbuk_df[['name','score','loc','lowest_price','category','loc2','SIG_CD']]
jeonbuk_df['lowest_price'] = jeonbuk_df['lowest_price'].str.replace('원','')
jeonbuk_df['lowest_price'] = jeonbuk_df['lowest_price'].str.replace(',','')
avgprice_df = jeonbuk_df[jeonbuk_df['lowest_price'] != '예약마감']
price_avg=round(avgprice_df['lowest_price'].astype(float).mean())
jeonbuk_df['lowest_price'] = jeonbuk_df['lowest_price'].str.replace('예약마감',str(price_avg))
jeonbuk_df['lowest_price'] = jeonbuk_df['lowest_price'].astype(float)
jeonbuk_df.loc[jeonbuk_df['category']=='f','category'] ='p'
jeonbuk_df.to_csv('전북통합.csv',sep=',',encoding='cp949')

# %%
######################### 전국 데이터 합성
total_df = pd.concat([seoul_df,kyunggi_df,incheon_df,gangwon_df,jeju_df,daejeon_df,choongbuk_df,choongnam_df,busan_df,ulsan_df,gyeongnam_df,daegu_df,gyeongbuk_df,gwangju_df,jeonnam_df,jeonbuk_df],ignore_index=True)
total_df.to_csv('전국(utf8).csv',sep=',',encoding='utf8')
